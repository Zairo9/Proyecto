# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Sofía Hernandez Zatarain, Cristian vazquez Plesent & Luis Eduardo Sánchez Soto.
#
# **Fecha:** 27 de marzo del 2023.
#
# **Expediente** :  & 734350 ######.
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Link Github**: https://github.com/Zairo9/Proyecto

# %%
import random
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Desempleo

# %%
data = pd.read_csv("Unemployment.csv")
data
# Out:
#        FIPS Code     State/Area  Year  Month  \
# 0              1        Alabama  1976      1
# 1              2         Alaska  1976      1
# 2              4        Arizona  1976      1
# 3              5       Arkansas  1976      1
# 4              6     California  1976      1
# ...          ...            ...   ...    ...
# 29887         51       Virginia  2022     12
# 29888         53     Washington  2022     12
# 29889         54  West Virginia  2022     12
# 29890         55      Wisconsin  2022     12
# 29891         56        Wyoming  2022     12
#
#       Total Civilian Non-Institutional Population in State/Area  \
# 0                                           2,605,000
# 1                                             232,000
# 2                                           1,621,000
# 3                                           1,536,000
# 4                                          15,621,000
# ...                                                  ...
# ...

# %%
sns.histplot(data["Percent (%) of State/Area's Population"], kde=True)
# Out:
# <AxesSubplot:xlabel="Percent (%) of State/Area's Population", ylabel='Count'>

# %%
sns.histplot(data["Percent (%) of Labor Force Unemployed in State/Area"], kde=True)
# Out:
# <AxesSubplot:xlabel='Percent (%) of Labor Force Unemployed in State/Area', ylabel='Count'>

# %%
sns.histplot(data["Percent (%) of Labor Force Employed in State/Area"], kde=True)
# Out:
# <AxesSubplot:xlabel='Percent (%) of Labor Force Employed in State/Area', ylabel='Count'>

# %%
sns.histplot(data[data["State/Area"]=="Alabama"]["Percent (%) of Labor Force Unemployed in State/Area"], kde=True);

# %%
sns.histplot(data[data["State/Area"]=="Alabama"]["Percent (%) of State/Area's Population"], kde=True)
# Out:
# <AxesSubplot:xlabel="Percent (%) of State/Area's Population", ylabel='Count'>

# %%
data_y = data.groupby('Year').mean().drop(columns=["Month", "FIPS Code"])
data_y.head()
# Out:
#       Percent (%) of State/Area's Population  \
# Year
# 1976                               62.489151
# 1977                               63.128302
# 1978                               63.780503
# 1979                               64.247484
# 1980                               64.425000
#
#       Percent (%) of Labor Force Employed in State/Area  \
# Year
# 1976                                          58.027830
# 1977                                          58.932547
# 1978                                          60.141981
# 1979                                          60.694811
# 1980                                          60.041352
#
#       Percent (%) of Labor Force Unemployed in State/Area
# Year
# 1976                                           7.166195
# 1977                                           6.678145
# 1978                                           5.730503
# 1979                                           5.565094
# ...

# %%
sns.histplot(data_y["Percent (%) of Labor Force Employed in State/Area"], kde=True)
# Out:
# <AxesSubplot:xlabel='Percent (%) of Labor Force Employed in State/Area', ylabel='Count'>

# %% [markdown]
# ### Poblacion

# %%
pop = pd.read_csv("population_usa.csv")
pop.head()
# Out:
#    Year  Population  Yearly % Change  Yearly Change  Migrants (net)  \
# 0  2020   331002651             0.59        1937734          954806
# 1  2019   329064917             0.60        1968652          954806
# 2  2018   327096265             0.62        2011509          954806
# 3  2017   325084756             0.64        2068761          954806
# 4  2016   323015995             0.67        2137685          954806
#
#    Median Age  Fertility Rate  Density (P/Km²)  Urban Pop %  Urban Population  \
# 0        38.3            1.78               36         82.8         273975139
# 1        37.7            1.85               36         82.5         271365914
# 2        37.7            1.85               36         82.2         268786714
# 3        37.7            1.85               36         81.9         266243516
# 4        37.7            1.85               35         81.7         263743312
#
#    Country's Share of World Pop  World Population  U.S. Global Rank
# ...

# %%
sns.histplot(pop["Yearly % Change"], kde=True)
# Out:
# <AxesSubplot:xlabel='Yearly % Change', ylabel='Count'>

# %%
pop = pop.drop([1, 2, 3, 4])
pop
# Out:
#     Year  Population  Yearly % Change  Yearly Change  Migrants (net)  \
# 0   2020   331002651             0.59        1937734          954806
# 5   2015   320878310             0.76        2373367          992343
# 6   2010   309011475             0.93        2803593         1085751
# 7   2005   294993511             0.93        2656520         1066979
# 8   2000   281710909             1.22        3309433         1771991
# 9   1995   265163745             1.01        2608687          892751
# 10  1990   252120309             0.95        2324097          673371
# 11  1985   240499825             0.94        2204694          676492
# 12  1980   229476354             0.93        2079021          754176
# 13  1975   219081251             0.90        1913582          577869
# 14  1970   209513341             0.96        1955933          311211
# 15  1965   199733676             1.36        2602621          367146
# 16  1960   186720571             1.69        3007047          424979
# ...

# %% [markdown]
# ### PIB

# %%
gdp = pd.read_csv("gdp.csv")
gdp
# Out:
#                     Country Name Code          1960          1961  \
# 0                          Aruba  ABW           NaN           NaN
# 1    Africa Eastern and Southern  AFE  1.931311e+10  1.972349e+10
# 2                    Afghanistan  AFG  5.377778e+08  5.488889e+08
# 3     Africa Western and Central  AFW  1.040428e+10  1.112805e+10
# 4                         Angola  AGO           NaN           NaN
# ..                           ...  ...           ...           ...
# 261                       Kosovo  XKX           NaN           NaN
# 262                  Yemen, Rep.  YEM           NaN           NaN
# 263                 South Africa  ZAF  7.575397e+09  7.972997e+09
# 264                       Zambia  ZMB  7.130000e+08  6.962857e+08
# 265                     Zimbabwe  ZWE  1.052990e+09  1.096647e+09
#
#              1962          1963          1964          1965          1966  \
# 0             NaN           NaN           NaN           NaN           NaN
# ...

# %%
gdp = pd.read_csv("gdp.csv")
gdp = gdp[gdp["Country Name"]=="United States"].drop(columns=["Country Name", "Code","Unnamed: 65"])
gdp= gdp.iloc[:, 1:].transpose()

# %%
gdp['Rendimiento'] = gdp[251].pct_change()
gdp.tail()
# Out:
#                251  Rendimiento
# 2016  1.874508e+13     0.027786
# 2017  1.954298e+13     0.042566
# 2018  2.061186e+13     0.054694
# 2019  2.143322e+13     0.039849
# 2020  2.095303e+13    -0.022404

# %%
sns.histplot(gdp['Rendimiento'],kde=True)
# Out:
# <AxesSubplot:xlabel='Rendimiento', ylabel='Count'>

# %% [markdown]
# ### population

# %%
pop = pd.read_csv("pop_us.csv")
pop=pop.drop(0)

# %%
pop =pop.iloc[:-78]
pop
# Out:
#           date   Population   Annual % Change
# 1   12/31/1951    150598453              1.56
# 2   12/31/1952    152941727              1.56
# 3   12/31/1953    155451199              1.64
# 4   12/31/1954    158205873              1.77
# 5   12/31/1955    161136449              1.85
# ..         ...          ...               ...
# 68  12/31/2018    332140037              0.71
# 69  12/31/2019    334319671              0.66
# 70  12/31/2020    335942003              0.49
# 71  12/31/2021    336997624              0.31
# 72  12/31/2022    338289857              0.38
#
# [72 rows x 3 columns]

# %%
sns.histplot(pop.iloc[:, 2], kde=True)
# Out:
# <AxesSubplot:xlabel=' Annual % Change', ylabel='Count'>

# %% [markdown]
# ### Inflacion

# %%
inf = pd.read_csv("inflacion.csv")
inf.head()
# Out:
#   Country Name Country Code                              Indicator Name  \
# 0        Aruba          ABW  Inflación, precios al consumidor (% anual)
# 1          NaN          AFE  Inflación, precios al consumidor (% anual)
# 2   Afganistán          AFG  Inflación, precios al consumidor (% anual)
# 3          NaN          AFW  Inflación, precios al consumidor (% anual)
# 4       Angola          AGO  Inflación, precios al consumidor (% anual)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  ...       2012  \
# 0  FP.CPI.TOTL.ZG   NaN   NaN   NaN   NaN   NaN   NaN  ...   0.627472
# 1  FP.CPI.TOTL.ZG   NaN   NaN   NaN   NaN   NaN   NaN  ...   9.158707
# 2  FP.CPI.TOTL.ZG   NaN   NaN   NaN   NaN   NaN   NaN  ...   6.441213
# 3  FP.CPI.TOTL.ZG   NaN   NaN   NaN   NaN   NaN   NaN  ...   4.578375
# 4  FP.CPI.TOTL.ZG   NaN   NaN   NaN   NaN   NaN   NaN  ...  10.277905
#
#        2013      2014      2015       2016       2017       2018       2019  \
# ...

# %%
inf = inf[inf["Country Name"]=="Estados Unidos"].drop(columns=["Country Name", "Country Code","Indicator Name", "Indicator Code"])
inf= inf.iloc[:, 1:].transpose()
inf
# Out:
#            251
# 1961  1.070724
# 1962  1.198773
# 1963  1.239669
# 1964  1.278912
# 1965  1.585169
# ...        ...
# 2017  2.130110
# 2018  2.442583
# 2019  1.812210
# 2020  1.233584
# 2021  4.697859
#
# [61 rows x 1 columns]

# %%
sns.histplot(inf,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ### Salario minimo

# %%
wage = pd.read_csv("Minimum Wage Data.csv",encoding='cp1252')
wage
# Out:
#       Year          State  State.Minimum.Wage  \
# 0     1968        Alabama             0.00000
# 1     1968         Alaska             2.10000
# 2     1968        Arizona             0.46800
# 3     1968       Arkansas             0.15625
# 4     1968     California             1.65000
# ...    ...            ...                 ...
# 2857  2020       Virginia             7.25000
# 2858  2020     Washington            13.50000
# 2859  2020  West Virginia             8.75000
# 2860  2020      Wisconsin             7.25000
# 2861  2020        Wyoming             5.15000
#
#       State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                                0.00                  1.15
# 1                               15.61                  1.15
# 2                                3.48                  1.15
# 3                                1.16                  1.15
# 4                               12.26                  1.15
# ...

# %%
sns.histplot(wage["State.Minimum.Wage.2020.Dollars"], kde=True)
# Out:
# <AxesSubplot:xlabel='State.Minimum.Wage.2020.Dollars', ylabel='Count'>

# %% [markdown]
# --------------

# %%
wage_mean = wage["State.Minimum.Wage.2020.Dollars"].mean()
wage_sd = wage["State.Minimum.Wage.2020.Dollars"].std()
wage_sim = np.random.normal(loc=wage_mean,scale=wage_sd,size=2500)

# %%
wage = pd.read_csv("Minimum Wage Data.csv",encoding='cp1252')
wage = wage.drop(wage[wage["State.Minimum.Wage.2020.Dollars"] == 0].index)
sns.histplot(wage["State.Minimum.Wage.2020.Dollars"], kde=True);
